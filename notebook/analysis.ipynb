# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
main = pd.read_csv('../data/main_loan_base.csv')
main
# Out:
#       loan_acc_num   customer_name                         customer_address  \
# 0       LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1       LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2       LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3       LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4       LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...            ...             ...                                      ...
# 49995   LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996   LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997   LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998   LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999   LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable        21916           4929.47               3
# 1           Two-Wheeler       121184          10254.50               1
# 2                   Car       487036         116183.86               0
# 3           Two-Wheeler        52125          10310.05               5
# 4      Consumer-Durable         8635           1051.25               0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler       222483          43088.19               2
# 49996       Two-Wheeler       104051           8666.54               6
# 49997       Two-Wheeler        51767           4101.24               1
# 49998       Two-Wheeler        77869          10652.77               0
# 49999       Two-Wheeler       241857          59258.17               0
#
#        number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                    0                  3                127             2
# 1                    0                  0                156             2
# 2                    1                 10                 22             3
# 3                    2                  9                 30             2
# 4                    1                  3                 62             2
# ...                ...                ...                ...           ...
# 49995                2                  8                 42             2
# 49996                2                  9                 86             3
# 49997                0                  4                156             2
# 49998                0                  5                 84             2
# 49999                2                  3                 67             1
#
#        interest  monthly_emi disbursal_date default_date
# 0          10.1      1012.32     2019-04-14   2020-07-31
# 1          11.8      5693.24     2015-04-14   2016-07-30
# 2          14.6     16788.02     2015-01-10   2015-04-18
# 3           9.6      2395.69     2018-02-07   2018-09-13
# 4           9.6       396.87     2014-12-25   2016-02-20
# ...         ...          ...            ...          ...
# 49995       9.6     10225.44     2021-02-03   2022-01-24
# 49996      12.6      3485.88     2013-01-12   2014-04-06
# 49997      14.0      2485.48     2016-05-01   2017-02-05
# 49998      14.9      3771.91     2013-08-29   2014-10-01
# 49999      11.6     21443.47     2014-05-19   2014-11-10
#
# [50000 rows x 15 columns]

# %%
monthly = pd.read_csv('../data/monthly_balance_base.csv')
monthly
# Out:
#         loan_acc_num        date  balance_amount
# 0         LN79307711  2010-03-26      407.343213
# 1         LN79307711  2010-04-25      545.431227
# 2         LN79307711  2010-05-25      861.932145
# 3         LN79307711  2010-06-24      562.082133
# 4         LN79307711  2010-07-24       37.768861
# ...              ...         ...             ...
# 4002485   LN46546410  2014-08-12    10875.235336
# 4002486   LN46546410  2014-09-11     8479.809099
# 4002487   LN46546410  2014-10-11     9745.974332
# 4002488   LN46546410  2014-11-10     9226.494566
# 4002489   LN46546410  2014-12-10     8851.138461
#
# [4002490 rows x 3 columns]

# %%
repayment = pd.read_csv('../data/repayment_base.csv')
repayment
# Out:
#        loan_acc_num  repayment_amount repayment_date
# 0        LN79307711       1012.320000     2019-05-18
# 1        LN79307711        667.987539     2019-06-20
# 2        LN79307711       1012.320000     2019-07-16
# 3        LN79307711       1012.320000     2019-08-16
# 4        LN79307711       1012.320000     2019-09-22
# ...             ...               ...            ...
# 626596   LN74765572       3771.910000     2014-10-22
# 626597   LN74765572       3771.910000     2014-11-15
# 626598   LN46546410      21443.470000     2014-06-12
# 626599   LN46546410      21443.470000     2014-07-18
# 626600   LN46546410      21443.470000     2014-08-18
#
# [626601 rows x 3 columns]

# %%
df = pd.concat([main, monthly, repayment], axis= 1)
df
# Out:
#          loan_acc_num  customer_name                         customer_address  \
# 0          LN79307711     Aarna Sura        09/506, Anand Path, Ongole 646592
# 1          LN88987787    Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2          LN78096023  Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3          LN56862431     Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4          LN77262680    Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...               ...            ...                                      ...
# 4002485           NaN            NaN                                      NaN
# 4002486           NaN            NaN                                      NaN
# 4002487           NaN            NaN                                      NaN
# 4002488           NaN            NaN                                      NaN
# 4002489           NaN            NaN                                      NaN
#
#                 loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0        Consumer-Durable      21916.0           4929.47             3.0
# 1             Two-Wheeler     121184.0          10254.50             1.0
# 2                     Car     487036.0         116183.86             0.0
# 3             Two-Wheeler      52125.0          10310.05             5.0
# 4        Consumer-Durable       8635.0           1051.25             0.0
# ...                   ...          ...               ...             ...
# 4002485               NaN          NaN               NaN             NaN
# 4002486               NaN          NaN               NaN             NaN
# 4002487               NaN          NaN               NaN             NaN
# 4002488               NaN          NaN               NaN             NaN
# 4002489               NaN          NaN               NaN             NaN
#
#          number_of_loans  missed_repayments  vintage_in_months  ...  interest  \
# 0                    0.0                3.0              127.0  ...      10.1
# 1                    0.0                0.0              156.0  ...      11.8
# 2                    1.0               10.0               22.0  ...      14.6
# 3                    2.0                9.0               30.0  ...       9.6
# 4                    1.0                3.0               62.0  ...       9.6
# ...                  ...                ...                ...  ...       ...
# 4002485              NaN                NaN                NaN  ...       NaN
# 4002486              NaN                NaN                NaN  ...       NaN
# 4002487              NaN                NaN                NaN  ...       NaN
# 4002488              NaN                NaN                NaN  ...       NaN
# 4002489              NaN                NaN                NaN  ...       NaN
#
#          monthly_emi  disbursal_date default_date  loan_acc_num        date  \
# 0            1012.32      2019-04-14   2020-07-31    LN79307711  2010-03-26
# 1            5693.24      2015-04-14   2016-07-30    LN79307711  2010-04-25
# 2           16788.02      2015-01-10   2015-04-18    LN79307711  2010-05-25
# 3            2395.69      2018-02-07   2018-09-13    LN79307711  2010-06-24
# 4             396.87      2014-12-25   2016-02-20    LN79307711  2010-07-24
# ...              ...             ...          ...           ...         ...
# 4002485          NaN             NaN          NaN    LN46546410  2014-08-12
# 4002486          NaN             NaN          NaN    LN46546410  2014-09-11
# 4002487          NaN             NaN          NaN    LN46546410  2014-10-11
# 4002488          NaN             NaN          NaN    LN46546410  2014-11-10
# 4002489          NaN             NaN          NaN    LN46546410  2014-12-10
#
#         balance_amount  loan_acc_num repayment_amount  repayment_date
# 0           407.343213    LN79307711      1012.320000      2019-05-18
# 1           545.431227    LN79307711       667.987539      2019-06-20
# 2           861.932145    LN79307711      1012.320000      2019-07-16
# 3           562.082133    LN79307711      1012.320000      2019-08-16
# 4            37.768861    LN79307711      1012.320000      2019-09-22
# ...                ...           ...              ...             ...
# 4002485   10875.235336           NaN              NaN             NaN
# 4002486    8479.809099           NaN              NaN             NaN
# 4002487    9745.974332           NaN              NaN             NaN
# 4002488    9226.494566           NaN              NaN             NaN
# 4002489    8851.138461           NaN              NaN             NaN
#
# [4002490 rows x 21 columns]

# %%
df.rename(columns={'loan_acc_num':'account_name'}, inplace= True)

# %% [markdown]
# # Data Cleaning

# %%
# Remove duplicates
df.drop_duplicates(subset= 'account_name')
# Out:
#          account_name  customer_name                         customer_address  \
# 0          LN79307711     Aarna Sura        09/506, Anand Path, Ongole 646592
# 1          LN88987787    Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2          LN78096023  Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3          LN56862431     Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4          LN77262680    Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...               ...            ...                                      ...
# 4002056           NaN            NaN                                      NaN
# 4002099           NaN            NaN                                      NaN
# 4002188           NaN            NaN                                      NaN
# 4002341           NaN            NaN                                      NaN
# 4002422           NaN            NaN                                      NaN
#
#                 loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0        Consumer-Durable      21916.0           4929.47             3.0
# 1             Two-Wheeler     121184.0          10254.50             1.0
# 2                     Car     487036.0         116183.86             0.0
# 3             Two-Wheeler      52125.0          10310.05             5.0
# 4        Consumer-Durable       8635.0           1051.25             0.0
# ...                   ...          ...               ...             ...
# 4002056               NaN          NaN               NaN             NaN
# 4002099               NaN          NaN               NaN             NaN
# 4002188               NaN          NaN               NaN             NaN
# 4002341               NaN          NaN               NaN             NaN
# 4002422               NaN          NaN               NaN             NaN
#
#          number_of_loans  missed_repayments  vintage_in_months  ...  interest  \
# 0                    0.0                3.0              127.0  ...      10.1
# 1                    0.0                0.0              156.0  ...      11.8
# 2                    1.0               10.0               22.0  ...      14.6
# 3                    2.0                9.0               30.0  ...       9.6
# 4                    1.0                3.0               62.0  ...       9.6
# ...                  ...                ...                ...  ...       ...
# 4002056              NaN                NaN                NaN  ...       NaN
# 4002099              NaN                NaN                NaN  ...       NaN
# 4002188              NaN                NaN                NaN  ...       NaN
# 4002341              NaN                NaN                NaN  ...       NaN
# 4002422              NaN                NaN                NaN  ...       NaN
#
#          monthly_emi  disbursal_date default_date  account_name        date  \
# 0            1012.32      2019-04-14   2020-07-31    LN79307711  2010-03-26
# 1            5693.24      2015-04-14   2016-07-30    LN79307711  2010-04-25
# 2           16788.02      2015-01-10   2015-04-18    LN79307711  2010-05-25
# 3            2395.69      2018-02-07   2018-09-13    LN79307711  2010-06-24
# 4             396.87      2014-12-25   2016-02-20    LN79307711  2010-07-24
# ...              ...             ...          ...           ...         ...
# 4002056          NaN             NaN          NaN    LN82044693  2018-09-12
# 4002099          NaN             NaN          NaN    LN37968463  2007-04-13
# 4002188          NaN             NaN          NaN    LN87152445  2004-05-14
# 4002341          NaN             NaN          NaN    LN74765572  2007-12-07
# 4002422          NaN             NaN          NaN    LN46546410  2009-06-09
#
#         balance_amount  account_name repayment_amount  repayment_date
# 0           407.343213    LN79307711      1012.320000      2019-05-18
# 1           545.431227    LN79307711       667.987539      2019-06-20
# 2           861.932145    LN79307711      1012.320000      2019-07-16
# 3           562.082133    LN79307711      1012.320000      2019-08-16
# 4            37.768861    LN79307711      1012.320000      2019-09-22
# ...                ...           ...              ...             ...
# 4002056    6107.087775           NaN              NaN             NaN
# 4002099    1990.440428           NaN              NaN             NaN
# 4002188    2817.812913           NaN              NaN             NaN
# 4002341    5116.259051           NaN              NaN             NaN
# 4002422    2566.321628           NaN              NaN             NaN
#
# [140903 rows x 21 columns]

# %%
# handle missing value 
df['default_date'].isnull().sum()
# Out:
# np.int64(3952490)

# %%
df.dropna(subset=['default_date'], inplace= True)
df
# Out:
#        account_name   customer_name                         customer_address  \
# 0        LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1        LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2        LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3        LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4        LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...             ...             ...                                      ...
# 49995    LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996    LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997    LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998    LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999    LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  interest  \
# 0                  0.0                3.0              127.0  ...      10.1
# 1                  0.0                0.0              156.0  ...      11.8
# 2                  1.0               10.0               22.0  ...      14.6
# 3                  2.0                9.0               30.0  ...       9.6
# 4                  1.0                3.0               62.0  ...       9.6
# ...                ...                ...                ...  ...       ...
# 49995              2.0                8.0               42.0  ...       9.6
# 49996              2.0                9.0               86.0  ...      12.6
# 49997              0.0                4.0              156.0  ...      14.0
# 49998              0.0                5.0               84.0  ...      14.9
# 49999              2.0                3.0               67.0  ...      11.6
#
#        monthly_emi  disbursal_date default_date  account_name        date  \
# 0          1012.32      2019-04-14   2020-07-31    LN79307711  2010-03-26
# 1          5693.24      2015-04-14   2016-07-30    LN79307711  2010-04-25
# 2         16788.02      2015-01-10   2015-04-18    LN79307711  2010-05-25
# 3          2395.69      2018-02-07   2018-09-13    LN79307711  2010-06-24
# 4           396.87      2014-12-25   2016-02-20    LN79307711  2010-07-24
# ...            ...             ...          ...           ...         ...
# 49995     10225.44      2021-02-03   2022-01-24    LN75707451  2013-05-23
# 49996      3485.88      2013-01-12   2014-04-06    LN75707451  2013-06-22
# 49997      2485.48      2016-05-01   2017-02-05    LN75707451  2013-07-22
# 49998      3771.91      2013-08-29   2014-10-01    LN75707451  2013-08-21
# 49999     21443.47      2014-05-19   2014-11-10    LN75707451  2013-09-20
#
#       balance_amount  account_name repayment_amount  repayment_date
# 0         407.343213    LN79307711      1012.320000      2019-05-18
# 1         545.431227    LN79307711       667.987539      2019-06-20
# 2         861.932145    LN79307711      1012.320000      2019-07-16
# 3         562.082133    LN79307711      1012.320000      2019-08-16
# 4          37.768861    LN79307711      1012.320000      2019-09-22
# ...              ...           ...              ...             ...
# 49995    1169.113582    LN80247164        95.840000      2013-02-18
# 49996    1579.501834    LN80247164        95.840000      2013-03-23
# 49997    1372.290218    LN80247164        95.840000      2013-04-29
# 49998    1245.845925    LN80247164        21.110561      2013-06-05
# 49999    1529.216552    LN80247164        95.840000      2013-07-04
#
# [50000 rows x 21 columns]

# %%
# convert disbursal_date, repayment_date into datetime
df['disbursal_date'] = pd.to_datetime(df['disbursal_date'])
df['default_date'] = pd.to_datetime(df['default_date'])
df
# Out:
#        account_name   customer_name                         customer_address  \
# 0        LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1        LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2        LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3        LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4        LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...             ...             ...                                      ...
# 49995    LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996    LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997    LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998    LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999    LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  interest  \
# 0                  0.0                3.0              127.0  ...      10.1
# 1                  0.0                0.0              156.0  ...      11.8
# 2                  1.0               10.0               22.0  ...      14.6
# 3                  2.0                9.0               30.0  ...       9.6
# 4                  1.0                3.0               62.0  ...       9.6
# ...                ...                ...                ...  ...       ...
# 49995              2.0                8.0               42.0  ...       9.6
# 49996              2.0                9.0               86.0  ...      12.6
# 49997              0.0                4.0              156.0  ...      14.0
# 49998              0.0                5.0               84.0  ...      14.9
# 49999              2.0                3.0               67.0  ...      11.6
#
#        monthly_emi  disbursal_date default_date  account_name        date  \
# 0          1012.32      2019-04-14   2020-07-31    LN79307711  2010-03-26
# 1          5693.24      2015-04-14   2016-07-30    LN79307711  2010-04-25
# 2         16788.02      2015-01-10   2015-04-18    LN79307711  2010-05-25
# 3          2395.69      2018-02-07   2018-09-13    LN79307711  2010-06-24
# 4           396.87      2014-12-25   2016-02-20    LN79307711  2010-07-24
# ...            ...             ...          ...           ...         ...
# 49995     10225.44      2021-02-03   2022-01-24    LN75707451  2013-05-23
# 49996      3485.88      2013-01-12   2014-04-06    LN75707451  2013-06-22
# 49997      2485.48      2016-05-01   2017-02-05    LN75707451  2013-07-22
# 49998      3771.91      2013-08-29   2014-10-01    LN75707451  2013-08-21
# 49999     21443.47      2014-05-19   2014-11-10    LN75707451  2013-09-20
#
#       balance_amount  account_name repayment_amount  repayment_date
# 0         407.343213    LN79307711      1012.320000      2019-05-18
# 1         545.431227    LN79307711       667.987539      2019-06-20
# 2         861.932145    LN79307711      1012.320000      2019-07-16
# 3         562.082133    LN79307711      1012.320000      2019-08-16
# 4          37.768861    LN79307711      1012.320000      2019-09-22
# ...              ...           ...              ...             ...
# 49995    1169.113582    LN80247164        95.840000      2013-02-18
# 49996    1579.501834    LN80247164        95.840000      2013-03-23
# 49997    1372.290218    LN80247164        95.840000      2013-04-29
# 49998    1245.845925    LN80247164        21.110561      2013-06-05
# 49999    1529.216552    LN80247164        95.840000      2013-07-04
#
# [50000 rows x 21 columns]

# %%
# 1. calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df['loan_amount'].quantile(0.25)
Q3 = df['loan_amount'].quantile(0.75)

# 2. Calculate the interquartile range(IQR)
IQR = Q3 - Q1

# 3. define the lower and upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 - 1.5 * IQR

# 4. filter and display the outliers
outliers = df[(df['loan_amount'] < lower_bound) | (df['loan_amount'] > upper_bound)]

print(f"lower bound: {lower_bound}")
print(f"upper bound: {upper_bound}")
print(f"Total Outliers found: {len(outliers)}")


# comparison plot 
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# 1.  boxplot to detect outliers points
sns.boxplot(x= df['loan_amount'], ax=axes[0], color='skyblue')
axes[0].set_title('Boxplot: spotting the whales')

# 2. histogram shape and skew
sns.histplot(df['loan_amount'], kde=True, ax=axes[1], color='orange')
axes[1].set_title('Histogram: vaisualizing the skew')
# Out:
# lower bound: -590272.5
# upper bound: -180800.5
# Total Outliers found: 50000
# Text(0.5, 1.0, 'Histogram: vaisualizing the skew')

# %%
# apply the log tranformation on loan_amount column.
df['loan_amount_log'] = np.log1p(df['loan_amount'])

# visiualization
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='loan_amount_log', 
            hue='loan_type', fill= True, 
            common_norm=False,
            alpha=0.5)

plt.title('log of loan amount grouped by category')
plt.xlabel('log loan amount')
plt.ylabel('density')
plt.show()

# %%
# 1. calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df['collateral_value'].quantile(0.25)
Q3 = df['collateral_value'].quantile(0.75)

# 2. Calculate the interquartile range(IQR)
IQR = Q3 - Q1

# 3. define the lower and upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 - 1.5 * IQR

# 4. filter and display the outliers
outliers = df[(df['collateral_value'] < lower_bound) | (df['collateral_value'] > upper_bound)]

print(f"lower bound: {lower_bound}")
print(f"upper bound: {upper_bound}")
print(f"Total Outliers found: {len(outliers)}")


# comparison plot 
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# 1.  boxplot to detect outliers points
sns.boxplot(x= df['collateral_value'], ax=axes[0], color='green')
axes[0].set_title('Boxplot: spotting the whales')

# 2. histogram shape and skew
sns.histplot(df['collateral_value'], kde=True, ax=axes[1], color='red')
axes[1].set_title('Histogram: vaisualizing the skew')
# Out:
# lower bound: -85146.67875
# upper bound: -26162.631250000006
# Total Outliers found: 50000
# Text(0.5, 1.0, 'Histogram: vaisualizing the skew')

# %%
# apply the log tranformation on loan_amount column.
df['collateral_value_log'] = np.log1p(df['collateral_value'])

# visiualization
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='collateral_value_log', 
            hue='loan_type', fill= True, 
            common_norm=False,
            alpha=0.5)

plt.title('log of loan amount grouped by category')
plt.xlabel('log loan amount')
plt.ylabel('density')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
# loan to collateral Ratio = loan_amount / collateral_value
df['loan_to_collateral_ratio'] = np.where(
    df['collateral_value'] > 0,
    df['loan_amount'] / df['collateral_value'],
    np.nan
)
df
# Out:
#       account_name   customer_name                         customer_address  \
# 0       LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1       LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2       LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3       LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4       LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...            ...             ...                                      ...
# 49995   LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996   LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997   LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998   LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999   LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  \
# 0                  0.0                3.0              127.0  ...
# 1                  0.0                0.0              156.0  ...
# 2                  1.0               10.0               22.0  ...
# 3                  2.0                9.0               30.0  ...
# 4                  1.0                3.0               62.0  ...
# ...                ...                ...                ...  ...
# 49995              2.0                8.0               42.0  ...
# 49996              2.0                9.0               86.0  ...
# 49997              0.0                4.0              156.0  ...
# 49998              0.0                5.0               84.0  ...
# 49999              2.0                3.0               67.0  ...
#
#        default_date account_name        date balance_amount account_name  \
# 0        2020-07-31   LN79307711  2010-03-26     407.343213   LN79307711
# 1        2016-07-30   LN79307711  2010-04-25     545.431227   LN79307711
# 2        2015-04-18   LN79307711  2010-05-25     861.932145   LN79307711
# 3        2018-09-13   LN79307711  2010-06-24     562.082133   LN79307711
# 4        2016-02-20   LN79307711  2010-07-24      37.768861   LN79307711
# ...             ...          ...         ...            ...          ...
# 49995    2022-01-24   LN75707451  2013-05-23    1169.113582   LN80247164
# 49996    2014-04-06   LN75707451  2013-06-22    1579.501834   LN80247164
# 49997    2017-02-05   LN75707451  2013-07-22    1372.290218   LN80247164
# 49998    2014-10-01   LN75707451  2013-08-21    1245.845925   LN80247164
# 49999    2014-11-10   LN75707451  2013-09-20    1529.216552   LN80247164
#
#       repayment_amount repayment_date  loan_amount_log collateral_value_log  \
# 0          1012.320000     2019-05-18         9.995018             8.503190
# 1           667.987539     2019-06-20        11.705074             9.235569
# 2          1012.320000     2019-07-16        13.096095            11.662938
# 3          1012.320000     2019-08-16        10.861419             9.240971
# 4          1012.320000     2019-09-22         9.063695             6.958686
# ...                ...            ...              ...                  ...
# 49995        95.840000     2013-02-18        12.312610            10.671027
# 49996        95.840000     2013-03-23        11.552646             9.067340
# 49997        95.840000     2013-04-29        10.854527             8.319288
# 49998        21.110561     2013-06-05        11.262796             9.273669
# 49999        95.840000     2013-07-04        12.396106            10.989676
#
#        loan_to_collateral_ratio
# 0                      4.445914
# 1                     11.817641
# 2                      4.191942
# 3                      5.055747
# 4                      8.214031
# ...                         ...
# 49995                  5.163433
# 49996                 12.006060
# 49997                 12.622280
# 49998                  7.309742
# 49999                  4.081412
#
# [50000 rows x 24 columns]

# %%
# EMI Burden Indicator
df['expected_emi'] = df['loan_amount'] / (df['tenure_years'] * 12)
df
# Out:
#       account_name   customer_name                         customer_address  \
# 0       LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1       LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2       LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3       LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4       LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...            ...             ...                                      ...
# 49995   LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996   LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997   LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998   LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999   LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  \
# 0                  0.0                3.0              127.0  ...
# 1                  0.0                0.0              156.0  ...
# 2                  1.0               10.0               22.0  ...
# 3                  2.0                9.0               30.0  ...
# 4                  1.0                3.0               62.0  ...
# ...                ...                ...                ...  ...
# 49995              2.0                8.0               42.0  ...
# 49996              2.0                9.0               86.0  ...
# 49997              0.0                4.0              156.0  ...
# 49998              0.0                5.0               84.0  ...
# 49999              2.0                3.0               67.0  ...
#
#       account_name        date  balance_amount account_name repayment_amount  \
# 0       LN79307711  2010-03-26      407.343213   LN79307711      1012.320000
# 1       LN79307711  2010-04-25      545.431227   LN79307711       667.987539
# 2       LN79307711  2010-05-25      861.932145   LN79307711      1012.320000
# 3       LN79307711  2010-06-24      562.082133   LN79307711      1012.320000
# 4       LN79307711  2010-07-24       37.768861   LN79307711      1012.320000
# ...            ...         ...             ...          ...              ...
# 49995   LN75707451  2013-05-23     1169.113582   LN80247164        95.840000
# 49996   LN75707451  2013-06-22     1579.501834   LN80247164        95.840000
# 49997   LN75707451  2013-07-22     1372.290218   LN80247164        95.840000
# 49998   LN75707451  2013-08-21     1245.845925   LN80247164        21.110561
# 49999   LN75707451  2013-09-20     1529.216552   LN80247164        95.840000
#
#       repayment_date loan_amount_log  collateral_value_log  \
# 0         2019-05-18        9.995018              8.503190
# 1         2019-06-20       11.705074              9.235569
# 2         2019-07-16       13.096095             11.662938
# 3         2019-08-16       10.861419              9.240971
# 4         2019-09-22        9.063695              6.958686
# ...              ...             ...                   ...
# 49995     2013-02-18       12.312610             10.671027
# 49996     2013-03-23       11.552646              9.067340
# 49997     2013-04-29       10.854527              8.319288
# 49998     2013-06-05       11.262796              9.273669
# 49999     2013-07-04       12.396106             10.989676
#
#       loan_to_collateral_ratio  expected_emi
# 0                     4.445914    913.166667
# 1                    11.817641   5049.333333
# 2                     4.191942  13528.777778
# 3                     5.055747   2171.875000
# 4                     8.214031    359.791667
# ...                        ...           ...
# 49995                 5.163433   9270.125000
# 49996                12.006060   2890.305556
# 49997                12.622280   2156.958333
# 49998                 7.309742   3244.541667
# 49999                 4.081412  20154.750000
#
# [50000 rows x 25 columns]

# %%
df['emi_burden_flag'] = np.where(
    (df['monthly_emi'] > df['expected_emi']) &
    (df['missed_repayments'] > 0),1,0
)
df
# Out:
#        account_name   customer_name                         customer_address  \
# 0        LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1        LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2        LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3        LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4        LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...             ...             ...                                      ...
# 49995    LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996    LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997    LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998    LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999    LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...        date  \
# 0                  0.0                3.0              127.0  ...  2010-03-26
# 1                  0.0                0.0              156.0  ...  2010-04-25
# 2                  1.0               10.0               22.0  ...  2010-05-25
# 3                  2.0                9.0               30.0  ...  2010-06-24
# 4                  1.0                3.0               62.0  ...  2010-07-24
# ...                ...                ...                ...  ...         ...
# 49995              2.0                8.0               42.0  ...  2013-05-23
# 49996              2.0                9.0               86.0  ...  2013-06-22
# 49997              0.0                4.0              156.0  ...  2013-07-22
# 49998              0.0                5.0               84.0  ...  2013-08-21
# 49999              2.0                3.0               67.0  ...  2013-09-20
#
#        balance_amount  account_name repayment_amount repayment_date  \
# 0          407.343213    LN79307711      1012.320000     2019-05-18
# 1          545.431227    LN79307711       667.987539     2019-06-20
# 2          861.932145    LN79307711      1012.320000     2019-07-16
# 3          562.082133    LN79307711      1012.320000     2019-08-16
# 4           37.768861    LN79307711      1012.320000     2019-09-22
# ...               ...           ...              ...            ...
# 49995     1169.113582    LN80247164        95.840000     2013-02-18
# 49996     1579.501834    LN80247164        95.840000     2013-03-23
# 49997     1372.290218    LN80247164        95.840000     2013-04-29
# 49998     1245.845925    LN80247164        21.110561     2013-06-05
# 49999     1529.216552    LN80247164        95.840000     2013-07-04
#
#       loan_amount_log collateral_value_log  loan_to_collateral_ratio  \
# 0            9.995018             8.503190                  4.445914
# 1           11.705074             9.235569                 11.817641
# 2           13.096095            11.662938                  4.191942
# 3           10.861419             9.240971                  5.055747
# 4            9.063695             6.958686                  8.214031
# ...               ...                  ...                       ...
# 49995       12.312610            10.671027                  5.163433
# 49996       11.552646             9.067340                 12.006060
# 49997       10.854527             8.319288                 12.622280
# 49998       11.262796             9.273669                  7.309742
# 49999       12.396106            10.989676                  4.081412
#
#        expected_emi  emi_burden_flag
# 0        913.166667                1
# 1       5049.333333                0
# 2      13528.777778                1
# 3       2171.875000                1
# 4        359.791667                1
# ...             ...              ...
# 49995   9270.125000                1
# 49996   2890.305556                1
# 49997   2156.958333                1
# 49998   3244.541667                1
# 49999  20154.750000                1
#
# [50000 rows x 26 columns]

# %%
# bounce risk score = based on cheques_bounces
# 0      0 = low risk
# 1-2    1 = medium risk
# >=3    2 = high risk
df['bounce_risk_score'] = np.select(
    [
        df['cheque_bounces'] == 0,
        df['cheque_bounces'].between(1, 2),
        df['cheque_bounces'] >= 3
    ],
    [0,1,2],
    default=0

)
df
# Out:
#        account_name   customer_name                         customer_address  \
# 0        LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1        LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2        LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3        LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4        LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...             ...             ...                                      ...
# 49995    LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996    LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997    LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998    LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999    LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  \
# 0                  0.0                3.0              127.0  ...
# 1                  0.0                0.0              156.0  ...
# 2                  1.0               10.0               22.0  ...
# 3                  2.0                9.0               30.0  ...
# 4                  1.0                3.0               62.0  ...
# ...                ...                ...                ...  ...
# 49995              2.0                8.0               42.0  ...
# 49996              2.0                9.0               86.0  ...
# 49997              0.0                4.0              156.0  ...
# 49998              0.0                5.0               84.0  ...
# 49999              2.0                3.0               67.0  ...
#
#        balance_amount  account_name  repayment_amount repayment_date  \
# 0          407.343213    LN79307711       1012.320000     2019-05-18
# 1          545.431227    LN79307711        667.987539     2019-06-20
# 2          861.932145    LN79307711       1012.320000     2019-07-16
# 3          562.082133    LN79307711       1012.320000     2019-08-16
# 4           37.768861    LN79307711       1012.320000     2019-09-22
# ...               ...           ...               ...            ...
# 49995     1169.113582    LN80247164         95.840000     2013-02-18
# 49996     1579.501834    LN80247164         95.840000     2013-03-23
# 49997     1372.290218    LN80247164         95.840000     2013-04-29
# 49998     1245.845925    LN80247164         21.110561     2013-06-05
# 49999     1529.216552    LN80247164         95.840000     2013-07-04
#
#       loan_amount_log collateral_value_log loan_to_collateral_ratio  \
# 0            9.995018             8.503190                 4.445914
# 1           11.705074             9.235569                11.817641
# 2           13.096095            11.662938                 4.191942
# 3           10.861419             9.240971                 5.055747
# 4            9.063695             6.958686                 8.214031
# ...               ...                  ...                      ...
# 49995       12.312610            10.671027                 5.163433
# 49996       11.552646             9.067340                12.006060
# 49997       10.854527             8.319288                12.622280
# 49998       11.262796             9.273669                 7.309742
# 49999       12.396106            10.989676                 4.081412
#
#        expected_emi emi_burden_flag  bounce_risk_score
# 0        913.166667               1                  2
# 1       5049.333333               0                  1
# 2      13528.777778               1                  0
# 3       2171.875000               1                  2
# 4        359.791667               1                  0
# ...             ...             ...                ...
# 49995   9270.125000               1                  1
# 49996   2890.305556               1                  2
# 49997   2156.958333               1                  1
# 49998   3244.541667               1                  0
# 49999  20154.750000               1                  0
#
# [50000 rows x 27 columns]

# %%
# repayment stress score = missed_repayments
'''
missed repayment              stress score
0                              0 (low stress)
1-2                            1 (medium stress)
3-5                            2 (high stress)
>5                             3 (severe stress)
'''

df['repayment_stress_score'] = np.select(
    [
        df['missed_repayments'] == 0,
        df['missed_repayments'].between(1, 2),
        df['missed_repayments'].between(3, 5),
        df['missed_repayments'] > 5
    ],
    [0, 1, 2, 3],
    default=0
)
df
# Out:
#        account_name   customer_name                         customer_address  \
# 0        LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1        LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2        LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3        LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4        LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...             ...             ...                                      ...
# 49995    LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996    LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997    LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998    LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999    LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  \
# 0                  0.0                3.0              127.0  ...
# 1                  0.0                0.0              156.0  ...
# 2                  1.0               10.0               22.0  ...
# 3                  2.0                9.0               30.0  ...
# 4                  1.0                3.0               62.0  ...
# ...                ...                ...                ...  ...
# 49995              2.0                8.0               42.0  ...
# 49996              2.0                9.0               86.0  ...
# 49997              0.0                4.0              156.0  ...
# 49998              0.0                5.0               84.0  ...
# 49999              2.0                3.0               67.0  ...
#
#        account_name  repayment_amount  repayment_date loan_amount_log  \
# 0        LN79307711       1012.320000      2019-05-18        9.995018
# 1        LN79307711        667.987539      2019-06-20       11.705074
# 2        LN79307711       1012.320000      2019-07-16       13.096095
# 3        LN79307711       1012.320000      2019-08-16       10.861419
# 4        LN79307711       1012.320000      2019-09-22        9.063695
# ...             ...               ...             ...             ...
# 49995    LN80247164         95.840000      2013-02-18       12.312610
# 49996    LN80247164         95.840000      2013-03-23       11.552646
# 49997    LN80247164         95.840000      2013-04-29       10.854527
# 49998    LN80247164         21.110561      2013-06-05       11.262796
# 49999    LN80247164         95.840000      2013-07-04       12.396106
#
#       collateral_value_log loan_to_collateral_ratio  expected_emi  \
# 0                 8.503190                 4.445914    913.166667
# 1                 9.235569                11.817641   5049.333333
# 2                11.662938                 4.191942  13528.777778
# 3                 9.240971                 5.055747   2171.875000
# 4                 6.958686                 8.214031    359.791667
# ...                    ...                      ...           ...
# 49995            10.671027                 5.163433   9270.125000
# 49996             9.067340                12.006060   2890.305556
# 49997             8.319288                12.622280   2156.958333
# 49998             9.273669                 7.309742   3244.541667
# 49999            10.989676                 4.081412  20154.750000
#
#        emi_burden_flag bounce_risk_score  repayment_stress_score
# 0                    1                 2                       2
# 1                    0                 1                       0
# 2                    1                 0                       3
# 3                    1                 2                       3
# 4                    1                 0                       2
# ...                ...               ...                     ...
# 49995                1                 1                       3
# 49996                1                 2                       3
# 49997                1                 1                       2
# 49998                1                 0                       2
# 49999                1                 0                       2
#
# [50000 rows x 28 columns]

# %%
# Loan Exposure = total loans per customer

exposure_df = df.groupby('customer_name').agg(
    total_exposure_amount = ('loan_amount','sum'),
    total_number_of_loans = ('loan_amount','count')
).reset_index()

print(exposure_df)

df = df.merge(exposure_df, on='customer_name', how='left')
df
# Out:
#         customer_name  total_exposure_amount  total_number_of_loans
# 0       Aaina Agarwal                14971.0                      1
# 1         Aaina Agate              1988293.0                      1
# 2      Aaina Aggarwal                69364.0                      1
# 3         Aaina Ahuja              1362313.0                      2
# 4          Aaina Apte               560124.0                      2
# ...               ...                    ...                    ...
# 38509      Zoya Walia               349465.0                      3
# 38510      Zoya Walla               269542.0                      1
# 38511    Zoya Warrior              1012829.0                      1
# 38512      Zoya Wason              1266310.0                      1
# 38513      Zoya Yadav               112720.0                      1
#
# [38514 rows x 3 columns]
#       account_name   customer_name                         customer_address  \
# 0       LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1       LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2       LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3       LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4       LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...            ...             ...                                      ...
# 49995   LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996   LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997   LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998   LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999   LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  \
# 0                  0.0                3.0              127.0  ...
# 1                  0.0                0.0              156.0  ...
# 2                  1.0               10.0               22.0  ...
# 3                  2.0                9.0               30.0  ...
# 4                  1.0                3.0               62.0  ...
# ...                ...                ...                ...  ...
# 49995              2.0                8.0               42.0  ...
# 49996              2.0                9.0               86.0  ...
# 49997              0.0                4.0              156.0  ...
# 49998              0.0                5.0               84.0  ...
# 49999              2.0                3.0               67.0  ...
#
#        repayment_date  loan_amount_log  collateral_value_log  \
# 0          2019-05-18         9.995018              8.503190
# 1          2019-06-20        11.705074              9.235569
# 2          2019-07-16        13.096095             11.662938
# 3          2019-08-16        10.861419              9.240971
# 4          2019-09-22         9.063695              6.958686
# ...               ...              ...                   ...
# 49995      2013-02-18        12.312610             10.671027
# 49996      2013-03-23        11.552646              9.067340
# 49997      2013-04-29        10.854527              8.319288
# 49998      2013-06-05        11.262796              9.273669
# 49999      2013-07-04        12.396106             10.989676
#
#       loan_to_collateral_ratio  expected_emi emi_burden_flag  \
# 0                     4.445914    913.166667               1
# 1                    11.817641   5049.333333               0
# 2                     4.191942  13528.777778               1
# 3                     5.055747   2171.875000               1
# 4                     8.214031    359.791667               1
# ...                        ...           ...             ...
# 49995                 5.163433   9270.125000               1
# 49996                12.006060   2890.305556               1
# 49997                12.622280   2156.958333               1
# 49998                 7.309742   3244.541667               1
# 49999                 4.081412  20154.750000               1
#
#       bounce_risk_score  repayment_stress_score total_exposure_amount  \
# 0                     2                       2               21916.0
# 1                     1                       0              121184.0
# 2                     0                       3              487036.0
# 3                     2                       3              413577.0
# 4                     0                       2                8635.0
# ...                 ...                     ...                   ...
# 49995                 1                       3              222483.0
# 49996                 2                       3              423326.0
# 49997                 1                       2               51767.0
# 49998                 0                       2               77869.0
# 49999                 0                       2              241857.0
#
#        total_number_of_loans
# 0                          1
# 1                          1
# 2                          1
# 3                          3
# 4                          1
# ...                      ...
# 49995                      1
# 49996                      2
# 49997                      1
# 49998                      1
# 49999                      1
#
# [50000 rows x 30 columns]

# %% [markdown]
# # LGD Calculation

# %%
# calculate recovery rate
df['recovery_rate'] = df['repayment_amount'] / df['loan_amount']
df
# Out:
#       account_name   customer_name                         customer_address  \
# 0       LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1       LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2       LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3       LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4       LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...            ...             ...                                      ...
# 49995   LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996   LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997   LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998   LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999   LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  \
# 0                  0.0                3.0              127.0  ...
# 1                  0.0                0.0              156.0  ...
# 2                  1.0               10.0               22.0  ...
# 3                  2.0                9.0               30.0  ...
# 4                  1.0                3.0               62.0  ...
# ...                ...                ...                ...  ...
# 49995              2.0                8.0               42.0  ...
# 49996              2.0                9.0               86.0  ...
# 49997              0.0                4.0              156.0  ...
# 49998              0.0                5.0               84.0  ...
# 49999              2.0                3.0               67.0  ...
#
#        loan_amount_log  collateral_value_log  loan_to_collateral_ratio  \
# 0             9.995018              8.503190                  4.445914
# 1            11.705074              9.235569                 11.817641
# 2            13.096095             11.662938                  4.191942
# 3            10.861419              9.240971                  5.055747
# 4             9.063695              6.958686                  8.214031
# ...                ...                   ...                       ...
# 49995        12.312610             10.671027                  5.163433
# 49996        11.552646              9.067340                 12.006060
# 49997        10.854527              8.319288                 12.622280
# 49998        11.262796              9.273669                  7.309742
# 49999        12.396106             10.989676                  4.081412
#
#        expected_emi emi_burden_flag bounce_risk_score repayment_stress_score  \
# 0        913.166667               1                 2                      2
# 1       5049.333333               0                 1                      0
# 2      13528.777778               1                 0                      3
# 3       2171.875000               1                 2                      3
# 4        359.791667               1                 0                      2
# ...             ...             ...               ...                    ...
# 49995   9270.125000               1                 1                      3
# 49996   2890.305556               1                 2                      3
# 49997   2156.958333               1                 1                      2
# 49998   3244.541667               1                 0                      2
# 49999  20154.750000               1                 0                      2
#
#        total_exposure_amount total_number_of_loans  recovery_rate
# 0                    21916.0                     1       0.046191
# 1                   121184.0                     1       0.005512
# 2                   487036.0                     1       0.002079
# 3                   413577.0                     3       0.019421
# 4                     8635.0                     1       0.117235
# ...                      ...                   ...            ...
# 49995               222483.0                     1       0.000431
# 49996               423326.0                     2       0.000921
# 49997                51767.0                     1       0.001851
# 49998                77869.0                     1       0.000271
# 49999               241857.0                     1       0.000396
#
# [50000 rows x 31 columns]

# %%
# calculate LGD
df['LGD'] = 1 - df['recovery_rate']
df
# Out:
#       account_name   customer_name                         customer_address  \
# 0       LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1       LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2       LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3       LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4       LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...            ...             ...                                      ...
# 49995   LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996   LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997   LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998   LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999   LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  \
# 0                  0.0                3.0              127.0  ...
# 1                  0.0                0.0              156.0  ...
# 2                  1.0               10.0               22.0  ...
# 3                  2.0                9.0               30.0  ...
# 4                  1.0                3.0               62.0  ...
# ...                ...                ...                ...  ...
# 49995              2.0                8.0               42.0  ...
# 49996              2.0                9.0               86.0  ...
# 49997              0.0                4.0              156.0  ...
# 49998              0.0                5.0               84.0  ...
# 49999              2.0                3.0               67.0  ...
#
#        collateral_value_log  loan_to_collateral_ratio  expected_emi  \
# 0                  8.503190                  4.445914    913.166667
# 1                  9.235569                 11.817641   5049.333333
# 2                 11.662938                  4.191942  13528.777778
# 3                  9.240971                  5.055747   2171.875000
# 4                  6.958686                  8.214031    359.791667
# ...                     ...                       ...           ...
# 49995             10.671027                  5.163433   9270.125000
# 49996              9.067340                 12.006060   2890.305556
# 49997              8.319288                 12.622280   2156.958333
# 49998              9.273669                  7.309742   3244.541667
# 49999             10.989676                  4.081412  20154.750000
#
#       emi_burden_flag bounce_risk_score repayment_stress_score  \
# 0                   1                 2                      2
# 1                   0                 1                      0
# 2                   1                 0                      3
# 3                   1                 2                      3
# 4                   1                 0                      2
# ...               ...               ...                    ...
# 49995               1                 1                      3
# 49996               1                 2                      3
# 49997               1                 1                      2
# 49998               1                 0                      2
# 49999               1                 0                      2
#
#       total_exposure_amount  total_number_of_loans recovery_rate       LGD
# 0                   21916.0                      1      0.046191  0.953809
# 1                  121184.0                      1      0.005512  0.994488
# 2                  487036.0                      1      0.002079  0.997921
# 3                  413577.0                      3      0.019421  0.980579
# 4                    8635.0                      1      0.117235  0.882765
# ...                     ...                    ...           ...       ...
# 49995              222483.0                      1      0.000431  0.999569
# 49996              423326.0                      2      0.000921  0.999079
# 49997               51767.0                      1      0.001851  0.998149
# 49998               77869.0                      1      0.000271  0.999729
# 49999              241857.0                      1      0.000396  0.999604
#
# [50000 rows x 32 columns]

# %%
# segement customers
def segment_lgd(lgd_value):
    if lgd_value > 0.6:
        return 'High'
    elif lgd_value > 0.3:
        return 'Medium'
    else:
        return 'low'
df['lgd_value'] = df['LGD'].apply(segment_lgd) # apply the 'high', 'medium', 'low'.
df
# Out:
#       account_name   customer_name                         customer_address  \
# 0       LN79307711      Aarna Sura        09/506, Anand Path, Ongole 646592
# 1       LN88987787     Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2       LN78096023   Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3       LN56862431      Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4       LN77262680     Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
# ...            ...             ...                                      ...
# 49995   LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996   LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997   LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998   LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999   LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#               loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0      Consumer-Durable      21916.0           4929.47             3.0
# 1           Two-Wheeler     121184.0          10254.50             1.0
# 2                   Car     487036.0         116183.86             0.0
# 3           Two-Wheeler      52125.0          10310.05             5.0
# 4      Consumer-Durable       8635.0           1051.25             0.0
# ...                 ...          ...               ...             ...
# 49995       Two-Wheeler     222483.0          43088.19             2.0
# 49996       Two-Wheeler     104051.0           8666.54             6.0
# 49997       Two-Wheeler      51767.0           4101.24             1.0
# 49998       Two-Wheeler      77869.0          10652.77             0.0
# 49999       Two-Wheeler     241857.0          59258.17             0.0
#
#        number_of_loans  missed_repayments  vintage_in_months  ...  \
# 0                  0.0                3.0              127.0  ...
# 1                  0.0                0.0              156.0  ...
# 2                  1.0               10.0               22.0  ...
# 3                  2.0                9.0               30.0  ...
# 4                  1.0                3.0               62.0  ...
# ...                ...                ...                ...  ...
# 49995              2.0                8.0               42.0  ...
# 49996              2.0                9.0               86.0  ...
# 49997              0.0                4.0              156.0  ...
# 49998              0.0                5.0               84.0  ...
# 49999              2.0                3.0               67.0  ...
#
#        loan_to_collateral_ratio  expected_emi  emi_burden_flag  \
# 0                      4.445914    913.166667                1
# 1                     11.817641   5049.333333                0
# 2                      4.191942  13528.777778                1
# 3                      5.055747   2171.875000                1
# 4                      8.214031    359.791667                1
# ...                         ...           ...              ...
# 49995                  5.163433   9270.125000                1
# 49996                 12.006060   2890.305556                1
# 49997                 12.622280   2156.958333                1
# 49998                  7.309742   3244.541667                1
# 49999                  4.081412  20154.750000                1
#
#       bounce_risk_score repayment_stress_score total_exposure_amount  \
# 0                     2                      2               21916.0
# 1                     1                      0              121184.0
# 2                     0                      3              487036.0
# 3                     2                      3              413577.0
# 4                     0                      2                8635.0
# ...                 ...                    ...                   ...
# 49995                 1                      3              222483.0
# 49996                 2                      3              423326.0
# 49997                 1                      2               51767.0
# 49998                 0                      2               77869.0
# 49999                 0                      2              241857.0
#
#       total_number_of_loans  recovery_rate       LGD  lgd_value
# 0                         1       0.046191  0.953809       High
# 1                         1       0.005512  0.994488       High
# 2                         1       0.002079  0.997921       High
# 3                         3       0.019421  0.980579       High
# 4                         1       0.117235  0.882765       High
# ...                     ...            ...       ...        ...
# 49995                     1       0.000431  0.999569       High
# 49996                     2       0.000921  0.999079       High
# 49997                     1       0.001851  0.998149       High
# 49998                     1       0.000271  0.999729       High
# 49999                     1       0.000396  0.999604       High
#
# [50000 rows x 33 columns]
